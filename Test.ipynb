# %% [markdown]
# <a href="https://colab.research.google.com/github/saeedzou/InsulatorDetSeg/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saeedzou/InsulatorDetSeg.git
# !git clone https://github.com/InsulatorData/InsulatorDataSet
# !pip -q install ultralytics
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os
import random
# Out:
# Cloning into 'InsulatorDetSeg'...
# remote: Enumerating objects: 53, done.
# remote: Total 53 (delta 0), reused 0 (delta 0), pack-reused 53
# Receiving objects: 100% (53/53), 53.99 MiB | 39.63 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Cloning into 'InsulatorDataSet'...
# remote: Enumerating objects: 1964, done.
# remote: Total 1964 (delta 0), reused 0 (delta 0), pack-reused 1964
# Receiving objects: 100% (1964/1964), 387.92 MiB | 54.77 MiB/s, done.
# Resolving deltas: 100% (1094/1094), done.
# Updating files: 100% (1946/1946), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.0/612.0 kB 10.4 MB/s eta 0:00:00

# %%
model = YOLO('/content/InsulatorDetSeg/runs/best.pt')

# %% [markdown]
# # Test

# %%
# path = "path/to/image"
# results = model(path)
# plt.imshow(results[0].plot()[:, :, [2,1,0]])
# plt.axis('off')
# plt.show()

# %%
# randomly select an image and run model
image_folder = '/content/InsulatorDataSet/Normal_Insulators/images'
img = random.choice(os.listdir(image_folder))
results = model(os.path.join(image_folder, img))
plt.imshow(results[0].plot()[:, :, [2,1,0]])
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/InsulatorDataSet/Normal_Insulators/images/2018.jpg: 480x640 1 insulator, 1619.5ms
# Speed: 14.7ms preprocess, 1619.5ms inference, 25.8ms postprocess per image at shape (1, 3, 480, 640)
